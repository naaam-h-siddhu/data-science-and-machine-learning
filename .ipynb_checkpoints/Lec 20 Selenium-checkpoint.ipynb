# %%
from selenium import webdriver
import selenium
driver = webdriver.Safari()
driver
# Out:
# <selenium.webdriver.safari.webdriver.WebDriver (session="6C9BB913-2EAE-4AF3-8650-ED8230BDADAD")>

# %%
driver.get('https://www.codingninjas.com/codestudio/auth?redirect=%2Fcodestudio%2Fhome')

# %%
driver.title
# Out:
# "Coding Ninjas - Learn coding online at India's best coding institute"

# %%
driver.back()

# %%
driver.forward()

# %%
driver.save_screenshot('resource/ss1.png')
# Out:
# True

# %%
driver.page_source
# Out:
# '<html lang="null"><head>\n    <meta charset="utf-8">\n    <title>Coding Ninjas - Learn coding online at India\'s best coding institute</title>\n\n    <meta name="google-site-verification" content="ASe_HQRsu8j61tGt95RROjXi07M380nMuoJ0Mu9rytk">\n    <meta name="title" content="Coding Ninjas - Learn coding online at India\'s best coding institute">\n    <meta property="og:title" content="Coding Ninjas - Learn coding online at India\'s best coding institute">\n    <meta name="description" content="With live 1:1 mentor support, get your doubts resolved via Audio Call, Video Call and Screen Share from the Teaching Assistants at Coding Ninjas.">\n    <meta property="og:description" content="With live 1:1 mentor support, get your doubts resolved via Audio Call, Video Call and Screen Share from the Teaching Assistants at Coding Ninjas.">\n    <meta property="og:image" content="https://files.codingninjas.in/0000000000000723.jpg">\n\n    <script src="https://connect.facebook.net/signals/config
# ...

# %%
from selenium.webdriver.common.by import By

# %%
but = driver.find_element(By.LINK_TEXT , "Advanced algorithms")
but.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# /var/folders/g0/4tjttlg17jn_d7b0wkct3ld00000gn/T/ipykernel_5475/3852411034.py in <module>
# ----> 1 but = driver.find_element(By.LINK_TEXT , "Advanced algorithms")
#       2 but.click()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     829             value = f'[name="{value}"]'
#     830
# --> 831         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     832
#     833     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     438         response = self.command_executor.execute(driver_command, params)
#     439         if response:
# ...

# %%
driver.get('https://www.google.com/')

# %%
but = driver.find_element(By.LINK_TEXT, 'Images')

# %%
but.click()

# %%
quit

# %%
driver.title
# Out:
# 'Google Images'

# %%
driver.back()

# %%
driver.get('https://www.facebook.com')

# %%
but = driver.find_element(By.LINK_TEXT, 'English (UK)')

# %%
but.click()

# %%
but = driver.find_element(By.LINK_TEXT, 'Create new account')

# %%
but.click()

# %%
driver.maximize_window()

# %%
driver.refresh()

# %%
driver.get("http://books.toscrape.com/")
c1 = driver.find_element(By.LINK_TEXT, "Music")
c1.click()

# %%
driver.find_element(By.PARTIAL_LINK_TEXT, "Band Could").click()

# %%
driver.get('https://www.codingninjas.com/')

# %%
but = driver.find_elements(By.TAG_NAME,"address")
but.click()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/g0/4tjttlg17jn_d7b0wkct3ld00000gn/T/ipykernel_7203/3757475430.py in <module>
#       1 but = driver.find_elements(By.TAG_NAME,"address")
# ----> 2 but.click()
#
# AttributeError: 'list' object has no attribute 'click'

# %%
driver.get('https://www.facebook.com/r.php')

# %%
f = driver.find_element(By.ID,'u_0_4_/v')
f
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# /var/folders/g0/4tjttlg17jn_d7b0wkct3ld00000gn/T/ipykernel_7203/3033970942.py in <module>
# ----> 1 f = driver.find_element(By.ID,'u_0_4_/v')
#       2 f
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     829             value = f'[name="{value}"]'
#     830
# --> 831         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     832
#     833     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     438         response = self.command_executor.execute(driver_command, params)
#     439         if response:
# ...

# %%
f.click()

# %%
quit()

# %%
driver.get('http://books.toscrape.com/')

# %%
ans = driver.find_element(By.XPATH,'html/head/title')

# %%
ans.get_attribute('outerHTML')
# Out:
# '<title>\n    All products | Books to Scrape - Sandbox\n</title>'

# %%
ans.get_attribute('innerHTML')
# Out:
# '\n    All products | Books to Scrape - Sandbox\n'

# %%
ans = driver.find_element(By.XPATH,'html/body/div/div/ul')
ans.get_attribute('innerHTML')
# Out:
# '\n        <li>\n            <a href="index.html">Home</a>\n        </li>\n        <li class="active">All products</li>\n    '

# %%
ans = driver.find_elements(By.XPATH,'//ul')
ans
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="817A662F-769E-4E9C-9231-08B50590EC50", element="node-360269AA-B0A9-4ACA-95A3-F295D719DEF6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="817A662F-769E-4E9C-9231-08B50590EC50", element="node-C8CD3F82-BF62-4571-9E4B-80BA1BEFE71A")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="817A662F-769E-4E9C-9231-08B50590EC50", element="node-4D23326B-A504-4598-BDCE-67A3F1CF15F1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="817A662F-769E-4E9C-9231-08B50590EC50", element="node-70696B55-E6AB-46D3-A63B-86D42E89DD57")>]

# %% [raw]
# for i in ans:
# print(i.get_attribute('outerHTML'))

# %%
driver.quit()

# %%
b  = driver.find_elements(By.XPATH, '//div[contains(@class, "h1")]')
b
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="817A662F-769E-4E9C-9231-08B50590EC50", element="node-8BCFF263-112D-4665-827C-192998A270D4")>]

# %%
b[0].get_attribute('innerHTML')
# Out:
# '<a href="index.html">Books to Scrape</a><small> We love being scraped!</small>\n'

# %%
from selenium import webdriver
import selenium
driver = webdriver.Safari()

# %%
driver.get('https://www.google.com/maps')

# %%
a = driver.find_element(By.NAME,'q')
a
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="A75EEA7E-9816-4450-82DA-19ED6260F516", element="node-671559F9-DFDB-4D5B-8C1B-45D9F55DF1E0")>

# %%
a.clear()

# %%
a.send_keys('tit bhopal')
a.submit()

# %%
b = driver.find_element(By.CLASS_NAME,'mL3xi')
b
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="A75EEA7E-9816-4450-82DA-19ED6260F516", element="node-D87A7D82-D316-4302-BBA8-99664D010B50")>

# %%
b.click()

# %%
html = driver.page_source

# %%
driver.get('https://www.dell.com/en-in')

# %%
flight = driver.find_element(By.ID,'mh-search-input')
flight
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="941ADB8E-ABE2-4540-B7B0-003153A433CC", element="node-ABE2A0EA-2142-4E29-987D-EA0CD5F2F1F9")>

# %%
flight.clear()
flight.send_keys('Gaming Laptop')

# %%
submit = driver.find_element(By.CLASS_NAME, 'mh-search-btn')
submit.get_attribute('outerHTML')
# Out:
# '<button class="mh-search-btn mh-search-cancel" tabindex="0" aria-label="Cancel Search" style="display: block;"></button>'

# %%
submit.click()

# %%
from bs4 import BeautifulSoup as bs

# %%
data = bs(html,'html.parser')

# %%
driver.close()

# %% [markdown]
# HANDLE DROPDOWN

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
driver.get('https://iqssdss2020.pythonanywhere.com/tutorial/form/search')

# %%
select = driver.find_element(By.ID,"search_grade")
# select.get_attribute('outerHTML')

# %%
from selenium.webdriver.support.select import Select

# %%
s = Select(select)

# %%
s.options
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="A5A9620D-76AF-4005-B235-F247616F3983", element="node-382F15A6-DDF7-4D5B-80FC-E835A934DA66")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="A5A9620D-76AF-4005-B235-F247616F3983", element="node-CDA0F1FE-EECE-4E5B-A737-E12DBD4DE856")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="A5A9620D-76AF-4005-B235-F247616F3983", element="node-DB822CFE-BE0F-447A-A9E5-58E2F738B243")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="A5A9620D-76AF-4005-B235-F247616F3983", element="node-144529D2-B4BD-4A81-9C73-093EF4B282A2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="A5A9620D-76AF-4005-B235-F247616F3983", element="node-B30B1A9B-E45F-4E5A-B434-515FBCC38093")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="A5A9620D-76AF-4005-B235-F247616F3983", element="node-B9FCB395-36CC-4AA5-9D0F-F2FF7E3D9F17")>,
# ...

# %%
s.select_by_value('K')

# %%
s.select_by_visible_text('3')

# %%
s.select_by_index(3)

# %% [raw]
# SCROLL WEBPAGE

# %%
driver.get('https://twitter.com/StackOverheards')

# %%
driver.execute_script('window.location ="https://www.google.com/"; ')

# %%
driver.execute_script('window.scrollBy(0,-11000)')

# %%
import time
for i in range(5):
    driver.execute_script('window.scrollBy(0,1000)')
    time.sleep(3)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
driver = webdriver.Safari()

# %%
driver.get('https://www.fiverr.com/categories/graphics-design?source=category_tree')

# %%
data = driver.page_source
