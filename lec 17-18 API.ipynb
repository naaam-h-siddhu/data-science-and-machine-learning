# %%
# https://codingninjas.in/api/v3/courses
# https://api.github.com/events
# https://dog.ceo/api/breeds/list/all
import requests
response = requests.get('https://codingninjas.in/api/v3/courses')
print(response.status_code)
print(response.encoding)
# print(response.text)
print(response.url)
print(type(response.headers))
header_info = response.headers
print(header_info['content-type'])
# print(header_info['content-Length'])

# %%
## Print the required output in given format
height=[189,185,195,149,189,147,154,174,169,195,159,192,155,191,153,157,140,144,172,157]
## Weight
weight=[87,110,104,61,104,92,111,90,103,81,80,101,51,79,107,110,129,145,139,110]

import matplotlib.pyplot as plt

import numpy as np
# plt.xticks(np.sort(weight))
plt.hist(height,bins = 5)
plt.hist(weight,bins = 5)
plt.show()

print(184,88)
# Out:
# 184 88

# %%
import json
json_data = '{"student":"siddhu"}'
py_data = json.loads(json_data)
print(py_data)
print(type(py_data))
print(py_data["student"])
# Out:
# {'student': 'siddhu'}
# <class 'dict'>
# siddhu

# %%
import requests
response =requests.get('https://api.github.com/events')
print(response.text)
# Out:
# [{"id":"33020642154","type":"PushEvent","actor":{"id":83863772,"login":"AtlantaIsHere","display_login":"AtlantaIsHere","gravatar_id":"","url":"https://api.github.com/users/AtlantaIsHere","avatar_url":"https://avatars.githubusercontent.com/u/83863772?"},"repo":{"id":712917239,"name":"AtlantaIsHere/bot-fqtxxvvzza","url":"https://api.github.com/repos/AtlantaIsHere/bot-fqtxxvvzza"},"payload":{"repository_id":712917239,"push_id":15656147764,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"44686b45c138c0f367050130a8dc0c0f5db6d94d","before":"4fdb5f46ea05a20ed9b8919a10e5f1695c1033fb","commits":[{"sha":"44686b45c138c0f367050130a8dc0c0f5db6d94d","author":{"email":"83863772+AtlantaIsHere@users.noreply.github.com","name":"huizsehuied"},"message":"Update date to actual date","distinct":true,"url":"https://api.github.com/repos/AtlantaIsHere/bot-fqtxxvvzza/commits/44686b45c138c0f367050130a8dc0c0f5db6d94d"}]},"public":true,"created_at":"2023-11-01T17:57:53Z"},{"id":"33020642160","type":"IssueCommentEvent","actor":{"id":82575774,"login":"mofinkc51","display_login":"mofinkc51","gravatar_id":"","url":"https://api.github.com/users/mofinkc51","avatar_url":"https://avatars.githubusercontent.com/u/82575774?"},"repo":{"id":686921054,"name":"mofinkc51/thaionlinedebate","url":"https://api.github.com/repos/mofinkc51/thaionlinedebate"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/mofinkc51/thaionlinedebate/issues/12","repository_url":"https://api.github.com/repos/mofinkc51/thaionlinedebate","labels_url":"https://api.github.com/repos/mofinkc51/thaionlinedebate/issues/12/labels{/name}","comments_url":"https://api.github.com/repos/mofinkc51/thaionlinedebate/issues/12/comments","events_url":"https://api.github.com/repos/mofinkc51/thaionlinedebate/issues/12/events","html_url":"https://github.com/mofinkc51/thaionlinedebate/pull/12","id":1972836904,"node_id":"PR_kwDOKPGVXs5eW9Xe","number":12,"title":"Debate topic v2","user":{"login":"mofinkc51","id":82575774,"node_id":"MDQ6VXNlcjgyNTc1Nzc0","avatar_url":"https://avatars.githubusercontent.com/u/82575774?v=4","gravatar_id":"","url":"https://api.github.com/users/mofinkc51","html_url":"https://github.com/mofinkc51","followers_url":"https://api.github.com/users/mofinkc51/followers","following_url":"https://api.github.com/users/mofinkc51/following{/other_user}","gists_url":"https://api.github.com/users/mofinkc51/gists{/gist_id}","starred_url":"https://api.github.com/users/mofinkc51/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/mofinkc51/subscriptions","organizations_url":"https://api.github.com/users/mofinkc51/orgs","repos_url":"https://api.github.com/users/mofinkc51/repos","events_url":"https://api.github.com/users/mofinkc51/events{/privacy}","received_events_url":"https://api.github.com/users/mofinkc51/received_events","type":"User","site_admin":false},"labels":[],"state":"open","locked":false,"assignee":null,"assignees":[],"milestone":null,"comments":1,"created_at":"2023-11-01T17:56:32Z","updated_at":"2023-11-01T17:57:53Z","closed_at":null,"author_association":"OWNER","active_lock_reason":null,"draft":false,"pull_request":{"url":"https://api.github.com/repos/mofinkc51/thaionlinedebate/pulls/12","html_url":"https://github.com/mofinkc51/thaionlinedebate/pull/12","diff_url":"https://github.com/mofinkc51/thaionlinedebate/pull/12.diff","patch_url":"https://github.com/mofinkc51/thaionlinedebate/pull/12.patch","merged_at":null},"body":null,"reactions":{"url":"https://api.github.com/repos/mofinkc51/thaionlinedebate/issues/12/reactions","total_count":0,"+1":0,"-1":0,"laugh":0,"hooray":0,"confused":0,"heart":0,"rocket":0,"eyes":0},"timeline_url":"https://api.github.com/repos/mofinkc51/thaionlinedebate/issues/12/timeline","performed_via_github_app":null,"state_reason":null},"comment":{"url":"https://api.github.com/repos/mofinkc51/thaionlinedebate/issues/comments/1789405828","html_url":"https://github.com/mofinkc51/thaionlinedebate/pull/12#issuecomment-178940 ...

# %%
import json
py_data = json.loads(response.text)
print(type(py_data))
data = py_data[0]
print(data['id'])
# Out:
# <class 'list'>
# 33020642154

# %%
p = requests.get('https://dog.ceo/api/breeds/list/all')
p.text
p_data = p.json()
print(type(p_data))
print(p_data['message'])
# Out:
# <class 'dict'>
# {'affenpinscher': [], 'african': [], 'airedale': [], 'akita': [], 'appenzeller': [], 'australian': ['shepherd'], 'basenji': [], 'beagle': [], 'bluetick': [], 'borzoi': [], 'bouvier': [], 'boxer': [], 'brabancon': [], 'briard': [], 'buhund': ['norwegian'], 'bulldog': ['boston', 'english', 'french'], 'bullterrier': ['staffordshire'], 'cattledog': ['australian'], 'cavapoo': [], 'chihuahua': [], 'chow': [], 'clumber': [], 'cockapoo': [], 'collie': ['border'], 'coonhound': [], 'corgi': ['cardigan'], 'cotondetulear': [], 'dachshund': [], 'dalmatian': [], 'dane': ['great'], 'deerhound': ['scottish'], 'dhole': [], 'dingo': [], 'doberman': [], 'elkhound': ['norwegian'], 'entlebucher': [], 'eskimo': [], 'finnish': ['lapphund'], 'frise': ['bichon'], 'germanshepherd': [], 'greyhound': ['italian'], 'groenendael': [], 'havanese': [], 'hound': ['afghan', 'basset', 'blood', 'english', 'ibizan', 'plott', 'walker'], 'husky': [], 'keeshond': [], 'kelpie': [], 'komondor': [], 'kuvasz': [], 'labradoodle': [], 'labrador': [], 'leonberg': [], 'lhasa': [], 'malamute': [], 'malinois': [], 'maltese': [], 'mastiff': ['bull', 'english', 'tibetan'], 'mexicanhairless': [], 'mix': [], 'mountain': ['bernese', 'swiss'], 'newfoundland': [], 'otterhound': [], 'ovcharka': ['caucasian'], 'papillon': [], 'pekinese': [], 'pembroke': [], 'pinscher': ['miniature'], 'pitbull': [], 'pointer': ['german', 'germanlonghair'], 'pomeranian': [], 'poodle': ['medium', 'miniature', 'standard', 'toy'], 'pug': [], 'puggle': [], 'pyrenees': [], 'redbone': [], 'retriever': ['chesapeake', 'curly', 'flatcoated', 'golden'], 'ridgeback': ['rhodesian'], 'rottweiler': [], 'saluki': [], 'samoyed': [], 'schipperke': [], 'schnauzer': ['giant', 'miniature'], 'segugio': ['italian'], 'setter': ['english', 'gordon', 'irish'], 'sharpei': [], 'sheepdog': ['english', 'shetland'], 'shiba': [], 'shihtzu': [], 'spaniel': ['blenheim', 'brittany', 'cocker', 'irish', 'japanese', 'sussex', 'welsh'], 'spitz': ['japanese'], 'springer': ['english'], 'stbernard': [], 'terrier': ['american', 'australian', 'bedlington', 'border', 'cairn', 'dandie', 'fox', 'irish', 'kerryblue', 'lakeland', 'norfolk', 'norwich', 'patterdale', 'russell', 'scottish', 'sealyham', 'silky', 'tibetan', 'toy', 'welsh', 'westhighland', 'wheaten', 'yorkshire'], 'tervuren': [], 'vizsla': [], 'waterdog': ['spanish'], 'weimaraner': [], 'whippet': [], 'wolfhound': ['irish']}

# %%
## Print the required output in given format
import requests as re
import json as js
response  = re.get('https://api.codingninjas.com/api/v3/courses')
py_data = js.loads(response.text)
# print(py_data)
for i in py_data['data']['courses']:
    if i['available_online']:
        print(i['name'])
# Out:
# Premium Competitive Programming Course
# C++ Foundation with Data Structures
# Premium Data Science Course
# Premium Android App Development
# Premium Machine Learning Course
# Premium Data structures and Algorithms [C++/Java/Python]
# System Design Course
# Ninja Competitive Programmer Track
# Premium Full Stack Web Development
# Machine Learning & Deep Learning Course
# Advanced  Front-End Web Development with React
# JAVA Foundation with Data Structures
# Ninja Android Developer Career Track
# Full Stack Web Development
# Ninja  Web Developer Career Track - NodeJS & ReactJs
# Data Science & Machine Learning Complete
# Grokking the Operating Systems Interview
# Ninja  Web Developer Career Track - NodeJS
# Competitive Programming Course
# Ninja Data Scientist Career Track
# Android Development with Kotlin
# Aptitude Preparation Course
# Ninja Machine Learning Engineer Career Track

# %%
import requests as re
import json as js
response  = re.get('https://api.codingninjas.com/api/v3/events?event_category=ALL_EVENTS&event_sub_category=All%20Time%20Favorites&tag_list=&offset=0&_ga=2.211464605.987578093.1681986605-1447846853.1675271392')
py_data = js.loads(response.text)
print(py_data['data']['events'])
# Out:
# [{'id': 3547, 'name': 'How to learn DSA', 'short_desc': 'Are you ready to embark on an exciting journey into the world of technology? Join us for our "How to learn DSA" webinar, where we will guide you through the steps to a successful and fulfilling tech career. This webinar is your roadmap to success.\r\n\r\n \r\n\r\n \r\n\r\nSpeaker: Aakansha Tewari, Microsoft\r\n\r\n \r\n\r\n \r\n\r\n \r\n\r\nWhat to Expect:\r\n\r\n \r\n\r\n \r\n\r\nInsider Insights: Hear from industry expert who will share the experiences and tips on navigating the tech landscape.\r\n\r\n \r\n\r\n \r\n\r\n \r\n\r\nCareer Pathways: Discover various career options in technology and DSA\r\n\r\n \r\n\r\n \r\n\r\nSkill Development: Learn about the essential skills and tools you need to excel in the tech field. \r\n\r\n \r\n\r\n \r\n\r\n \r\n\r\nQ&A Session: Get answers to your burning questions from our expert.\r\n\r\n \r\n\r\n🎟️ Don\'t Forget to Register:\r\nSeats are limited, and this is your chance to kickstart or supercharge your career in the world of DSA. Register now to secure your spot.\r\n\r\n\r\n \r\n\r\n\r\nThis webinar will provide you with valuable insights and a clear roadmap to achieve your goals. Don\'t miss out on this opportunity to take the next step in your tech journey.', 'cover_picture': 'https://files.codingninjas.in/coding-webinar-05-1-30826-31538.jpg', 'registration_start_time': 1698666360, 'registration_end_time': 1699363800, 'event_start_time': 1699367400, 'event_end_time': 1699371000, 'venue': 'Online', 'fees': 0, 'currency': 'INR', 'registration_status': 'REGISTRATIONS_OPEN', 'user_already_registered': None, 'start_time': 1698666360, 'end_time': 1699363800, 'registered_users': {'top_users': [{'name': 'Saakshi Shrestha', 'image_url': 'https://files.codingninjas.com/profile41320259cfc5bd38f50738fe828ec2e10e53445.webp'}, {'name': 'Abhinav Patel', 'image_url': 'https://files.codingninjas.com/profile45109147789f6d1a562677251df69a29e3a0756.webp'}, {'name': 'nikhil kumar', 'image_url': 'https://lh3.googleusercontent.com/a/ACg8ocI3jGRGAYaVbhPmtWMdTJny6jsvFofxQMs326szpq2t=s96-c'}, {'name': 'Deep Chauhan', 'image_url': 'https://lh3.googleusercontent.com/a/AEdFTp5c5HEuLdTfxNwlsUoNEYqrG-XwIdsNFsQR_-gg=s96-c'}, {'name': 'Akash Birthal ', 'image_url': 'https://files.codingninjas.in/article_images/profile2438592635dae821ed89be7e86a2c10581e9710.webp'}], 'other_users_count': 156, 'show_users_count': True}, 'seats_left': 9839, 'seats_filled': 161, 'slug': 'how-to-learn-dsa', 'orderable_key': 'EV-3547', 'has_started': False, 'highlight_event': False, 'card_tags': [], 'mobile_cover_picture': 'https://files.codingninjas.in/coding-webinar-10-30260-32005.jpg', 'is_college_specific': True, 'event_category': 'WEBINAR', 'event_sub_category': 'All Time Favorites', 'user_ranking': None, 'high_priority': False}, {'id': 3544, 'name': 'SDE INTERNSHIPS : THE INSIDE SCOOP', 'short_desc': ' \r\nAre you ready to embark on an exciting journey into the world of technology? Join us for our "SDE INTERNSHIPS : THE INSIDE SCOOP" webinar, where we will guide you through the steps to a successful and fulfilling tech career. This webinar is your roadmap to success.\r\n\r\n \r\n\r\nSpeaker: Shubhangi Gupta, Airtel\r\n\r\n \r\n\r\nWhat to Expect:\r\n\r\n \r\n\r\nInsider Insights: Hear from industry expert who will share the experiences and tips on navigating the tech landscape.\r\n\r\n  \r\n\r\nCareer Pathways: Discover various career options in technology and SDE \r\n\r\n \r\n\r\nSkill Development: Learn about the essential skills and tools you need to excel in the tech field. \r\n\r\n \r\n\r\nQ&A Session: Get answers to your burning questions from our expert.\r\n\r\n🎟️ Don\'t Forget to Register:\r\n\r\nSeats are limited, and this is your chance to kickstart or supercharge your career in the world of SDE. Register now to secure your spot.\r\n\r\nThis webinar will provide you with valuable insights and a clear roadmap to achieve your goals. Don\'t miss out on this opportunity  ...

# %%
import requests as re
import json
response = re.get("https://api.openaq.org/v2/cities")
p = response.json()['results']
# ans = 0
# for i in p:
#     if i['country'] == 'AU':
#         ans += i['count']
# print(ans)`

# %%
import requests as re
import json
h_key = '630a1c83-5289-493d-9193-e16926555598'
response = re.get('https://holidayapi.com/v1/holidays', params = {"key" : h_key,"country":"IN","year":2022,"month":10,"day":2  })
p_data = response.json()
p_data = p_data["holidays"]
print(p_data[0]['name'])
# Out:
# Mahatma Gandhi's Birthday

# %%
#post
import requests

# %% [markdown]
# #Authentication

# %%
import requests
import json 
from requests.auth import HTTPBasicAuth
username = 'naaam-h-siddhu'
url = 'https://api.github.com/repos/google/science-journal-ios/languages'
token = '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'

response = requests.get(url, auth=(username,token))
p = json.loads(response.text)
response.url
for i in p:
    print(i)
# Out:
# message
# documentation_url

# %%
## Open and read data file as specified in the question
## Print the required output in given format
import requests
import json

data = {'client_id':'a89c48abbcc908572f92','redirect_uri':'https://www.google.com/','scope':'(no scope)',
        'state':'random_123','allow_signup':'false'}
response = requests.get('https://github.com/login/oauth/authorize',params=data)




data = {'client_id':'a89c48abbcc908572f92','client_secret':'68ab50cfcc7d4c094cf0395a084208e989666c94',
        'code':'f3a586574e7507e6e221','redirect_uri':'https://www.google.com/','state':'random_123'}

post = requests.post('https://github.com/login/oauth/access_token',data=data)



header = {'User-Agent':'kevi15cs','Authorization': 'token  a47df110107e21799f1529f1e1ce3f468f6b5a6d','type':'all'}
r = requests.get("https://api.github.com/orgs/CodingNinjasCodes/repos",headers=header)
data = r.json()
for i in data:
    print(i)
# Out:
# message
# documentation_url

# %%
#client id  : TiISXqp3WVkchBTA9AzErA
#secret code : wJhSHXQayydDbK7WH3swDXsUxFZZ-A

# %%
import requests
import json



data={'client-id':'TiISXqp3WVkchBTA9AzErA','response_type':'code','state':'random_123','redirect_uri':'https://www.google.com/','scope':'read'}

response=requests.get('https://www.reddit.com/api/v1/authorize',params=data)
print(response.url)
# Out:
# https://www.reddit.com/login/?dest=https%3A%2F%2Fwww.reddit.com%2Fapi%2Fv1%2Fauthorize%3Fclient-id%3DTiISXqp3WVkchBTA9AzErA%26response_type%3Dcode%26state%3Drandom_123%26redirect_uri%3Dhttps%253A%252F%252Fwww.google.com%252F%26scope%3Dread

# %%
#code  = sXOoIEf3igiszqirLj3ek3zb7RT6dA#_

# %%
import requests
data = {'grant_type' : 'authorization_code','code' : 'Lid1iOogetqw57c5bRpuDCA_kTRQ6Q','redirect_uri': 'https://www.google.com/',}
r = requests.post('https://reddit.com/api/v1/access_token',data= data,
                  auth = ('TiISXqp3WVkchBTA9AzErA','wJhSHXQayydDbK7WH3swDXsUxFZZ-A'),
                  headers = {'User-Agent':'siddhu singh'})
print(r.text)
r.status_code
# Out:
# {"message": "Unauthorized", "error": 401}
# 401

# %%
## Open and read data file as specified in the question
## Print the required output in given format
import requests
import json
username = 'naaam-h-siddhu'
url = 'https://api.github.com/repos/google/science-journal-ios/languages'
token = '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'

print(response.url)
# Out:
# https://www.reddit.com/login/?dest=https%3A%2F%2Fwww.reddit.com%2Fapi%2Fv1%2Fauthorize%3Fclient_id%3DTiISXqp3WVkchBTA9AzErA%26response_type%3Dcode%26state%3Drandom_123%26redirect_uri%3Dhttps%253A%252F%252Fwww.google.com%252F%26scope%3Dread

# %%
data = {'client_id':'TiISXqp3WVkchBTA9AzErA','client_secret':'wJhSHXQayydDbK7WH3swDXsUxFZZ-A',
        'code':'f3a586574e7507e6e221','redirect_uri':'https://www.google.com/','state':'random_123'}

post = requests.post('https://github.com/login/oauth/access_token',data=data)



header = {'User-Agent':'kevi15cs','Authorization': 'token  a47df110107e21799f1529f1e1ce3f468f6b5a6d','type':'all'}
r = requests.get("https://api.github.com/orgs/CodingNinjasCodes/repos",headers=header)
data = r.json()
for i in data:
    if (i['fork']== False):
        print(i['name'],i['watchers_count'],i['forks_count'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 12
#      10 data = r.json()
#      11 for i in data:
# ---> 12     if (i['fork']== False):
#      13         print(i['name'],i['watchers_count'],i['forks_count'])
#
# TypeError: string indices must be integers, not 'str'

# %%
import requests as re
import json 
API_KEY = 'f54fb2cf836df163dcdcab183a2bc3fc'

# Set up the endpoint URL
url = f'https://api.themoviedb.org/3/search/movie?api_key={API_KEY}'
response = re.get(url)
print(response.url)

# %%
import requests

# Replace YOUR_API_KEY with your actual API key
API_KEY = 'f54fb2cf836df163dcdcab183a2bc3fc'

# Set up the endpoint URL
url = f'https://api.themoviedb.org/3/search/movie?api_key={API_KEY}'

# Make the HTTP GET request
response = requests.get(url)

# Parse the JSON response
data = response.json()

# Extract the vote count and vote average
vote_count = data['results'][0]['vote_count']
vote_average = data['results'][0]['vote_average']

# Print the results
print(f'Vote count: {vote_count}')
print(f'Vote average: {vote_average}')

# %%
import requests

# Replace YOUR_API_KEY with your actual API key
API_KEY = 'f54fb2cf836df163dcdcab183a2bc3fc'

# Set up the API endpoint URL
query = 'Inception' # The movie you want to get the ID for
url = f'https://api.themoviedb.org/3/search/movie?api_key={API_KEY}&query={query}'

# Make the HTTP GET request
response = requests.get(url)

# Parse the JSON response
data = response.json()

# Extract the ID of the first movie in the search results
movie_id = data['results'][0]['id']

# Print the ID
print(f'The ID of {query} is {movie_id}')

# %%
import requests
API_KEY = 'f54fb2cf836df163dcdcab183a2bc3fc'
url = f'https://api.themoviedb.org/3/discover/movie?api_key={API_KEY}&sort_by=vote_average.desc&with_original_language=en&region=US'

response = requests.get(url)
data = response.json()

# print(response.url)
movies = []
for i in data['results']:
    if i['original_language'] == 'en':
        movies.append(i)
movies = movies[:10]

genre_url = f'https://api.themoviedb.org/3/genre/movie/list?api_key={API_KEY}&language=en-US'
genre_response = requests.get(genre_url)
genre_data = genre_response.json()

# Create a dictionary of genre IDs to genre names
genre_dict = {genre['id']: genre['name'] for genre in genre_data['genres']}

# Print the movie titles and genres
for movie in movies:
    title = movie['title']
    genre_ids = movie['genre_ids']
    genres = [genre_dict[genre_id] for genre_id in genre_ids]
    print(title,"-",end=" ")
    for i in genres:
        print(i,end = ", ")
    print()

# %%
import requests
ACCESS_TOKEN = "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"

# Set the base URL for the Github API
BASE_URL = "https://api.github.com"

# Set the name of the organization
ORG_NAME = "CodingNinjasCodes"

# Build the API endpoint URL
api_endpoint = f"{BASE_URL}/orgs/{ORG_NAME}/repos"

# Set the headers with the access token
headers = {
    "Authorization": f"Bearer {ACCESS_TOKEN}",
    "Accept": "application/vnd.github.v3+json"
}

# Send the API request to fetch the repositories
response = requests.get(api_endpoint, headers=headers)

# Check if the API request was successful
if response.status_code == 200:
    # Iterate over the list of repositories
    for repo in response.json():
        # Check if the repository is not a fork
        if not repo["fork"]:
            # Print the name of the repository with its watch count and fork count
            print(f"{repo['name']} {repo['watchers_count']} {repo['forks_count']}")
else:
    # Print an error message if the API request failed
    print(f"Error: {response.status_code} - {response.reason}")

# %%
import requests

# Set the access token
ACCESS_TOKEN = "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"

# Set the base URL for the Github API
BASE_URL = "https://api.github.com"

# Set the name of the organization
ORG_NAME = "fossasia"

# Build the API endpoint URL
api_endpoint = f"{BASE_URL}/orgs/{ORG_NAME}/repos"

# Set the headers with the access token
headers = {
    "Authorization": f"Bearer {ACCESS_TOKEN}",
    "Accept": "application/vnd.github.v3+json"
}

# Send the API request to fetch the repositories
response = requests.get(api_endpoint, headers=headers)

# Check if the API request was successful
if response.status_code == 200:
    # Iterate over the list of repositories and print their names
    for repository in response.json():
        print(repository["name"])
else:
    # Print an error message if the API request failed
    print(f"Error: {response.status_code} - {response.reason}")

# %%
import requests

# Replace YOUR_API_KEY with your actual API key
API_KEY = 'f54fb2cf836df163dcdcab183a2bc3fc'

# Search for the movie ID for 'Inception'
url = 'https://api.themoviedb.org/3/search/movie'
params = {
    'api_key': API_KEY,
    'query': 'Inception',
    'language': 'en-US',
    'page': 1,
}
response = requests.get(url, params=params)
response_json = response.json()
movie_id = response_json['results'][0]['id']

# Get the top 5 similar movies to 'Inception'
url = f'https://api.themoviedb.org/3/movie/{movie_id}/similar'
params = {
    'api_key': API_KEY,
    'language': 'en-US',
    'page': 1,
}
response = requests.get(url, params=params)
response_json = response.json()
similar_movies = response_json['results'][:5]

# Print the names of the similar movies
for movie in similar_movies:
    print(movie['original_title'])

# %%
import requests
API_KEY = 'f54fb2cf836df163dcdcab183a2bc3fc'
url = 'https://api.themoviedb.org/3/search/movie'
param = {'api_key' : API_KEY,
         'query' :'Inception'
        }
response = requests.get(url, params=params)
response_json = response.json()

# Extract the movie ID of the first result (assuming it's the movie we want)
movie_id = response_json['results'][0]['id']
movie_id

# %%
import json
import requests
API_key = 'f54fb2cf836df163dcdcab183a2bc3fc'
url= f'https://api.themoviedb.org/3/person/popular?api_key={API_key}&language=en-US&page=1'
response = requests.get(url)
data = json.loads(response.content)
person = data['results'][0]
name = person['name']
person_id = person['id']
response = requests.get(f'https://api.themoviedb.org/3/person/{person_id}?api_key={API_key}&language=en-US')
data = json.loads(response.content)
birthplace = data['place_of_birth']
print(person_id)
print(birthplace)

# %%
import json
import requests
API_key = 'f54fb2cf836df163dcdcab183a2bc3fc'
url= f'https://api.themoviedb.org/3/person/?api_key={API_key}&language=en-US&page=1'
response = requests.get(url,params = {'query' :'Alia Bhatt'})
response.url

# %%
import requests
import json

# Replace YOUR_API_KEY with your actual TMDb API key
api_key = 'f54fb2cf836df163dcdcab183a2bc3fc'

# Define a dictionary to store the movie titles and their corresponding TMDb movie IDs
movie_titles = {
    'Top Gun': 744,
    'Mission: Impossible - Fallout': 353081,
    'Minority Report': 180,
    'Edge of Tomorrow': 137113
}

# Define a dictionary to store the character names
character_names = {}

# Iterate through the movie titles and their corresponding TMDb movie IDs
for title, movie_id in movie_titles.items():
    # Make a request to TMDb API to retrieve the movie details
    response = requests.get(f'https://api.themoviedb.org/3/movie/{movie_id}?api_key={api_key}&language=en-US')
    
    # Parse the response content as JSON
    data = json.loads(response.content)
    
    # Retrieve the cast of the movie
    cast = data['credits']['cast']
    
    # Iterate through the cast to find the character played by Tom Cruise
    for actor in cast:
        if actor['name'] == 'Tom Cruise':
            # Store the character name in the dictionary
            character_names[title] = actor['character']
            break

# Print the character names
for title, character_name in character_names.items():
    print(f'Tom Cruise played {character_name} in "{title}"')

# %%
import requests as re
import json 
API_KEY = 'f54fb2cf836df163dcdcab183a2bc3fc'
name = 'Alia Bhatt'
url= f'https://api.themoviedb.org/3/search/person?api_key={API_KEY}&query={name}'
response = re.get(url)
py = response.json()
person_id = py['results'][0]['id']
new_url = f'https://api.themoviedb.org/3/person/{person_id}/external_ids?api_key={API_KEY}'
r = re.get(new_url)
q = r.json()
print(q['instagram_id'])
print(q['twitter_id'])

# %%
import requests
import json 
api_key= 'f54fb2cf836df163dcdcab183a2bc3fc'
base_url = 'https://api.themoviedb.org/3'

# A dictionary mapping movie titles to their TMDB IDs
movie_ids = {
    'Top Gun': '744',
    'Mission: Impossible - Fallout': '353081',
    'Minority Report': '180',
    'Edge of Tomorrow': '137113'
}

# The ID for Tom Cruise in TMDB
person_id = '500'

# Iterate over the movies and retrieve the character names for each one
for movie_title, movie_id in movie_ids.items():
    # Construct the API request URL for the movie credits for Tom Cruise
    credits_url = f'{base_url}/person/{person_id}/movie_credits?api_key={api_key}'

    # Send the request to the API and retrieve the response
    response = requests.get(credits_url)

    # Extract the JSON data from the response
    credits_data = response.json()

    # Find the movie in the credits data
    movie = next((m for m in credits_data['cast'] if m['id'] == int(movie_id)), None)
    character_name = movie['character']
    print(character_name)

# %%
import requests

# Your TMDB API key
api_key = 'f54fb2cf836df163dcdcab183a2bc3fc'
base_url = 'https://api.themoviedb.org/3'
tv_show_id = '1668'
tv_show_url = f'{base_url}/tv/{tv_show_id}?api_key={api_key}'

response = requests.get(tv_show_url)

tv_show_data = response.json()
print(response.url)
print(f'{tv_show_data["overview"]}')

# %%
import requests

# Your TMDB API key
api_key = 'f54fb2cf836df163dcdcab183a2bc3fc'

# The base URL for TMDB API requests
base_url = 'https://api.themoviedb.org/3'

# The ID for "The Big Bang Theory" TV show in TMDB
tv_show_id = '1418'

# The season and episode numbers for the episode you want to retrieve
season_number = '6'
episode_number = '5'

# Construct the API request URL for the episode details
episode_url = f'{base_url}/tv/{tv_show_id}/season/{season_number}/episode/{episode_number}?api_key={api_key}'

# Send the request to the API and retrieve the response
response = requests.get(episode_url)

# Extract the JSON data from the response
episode_data = response.json()

# Print out the name and air date for the episode
print(episode_data["name"])
print(episode_data["air_date"])

# %%
import requests

# Your TMDB API key
api_key = 'f54fb2cf836df163dcdcab183a2bc3fc'

# The base URL for TMDB API requests
base_url = 'https://api.themoviedb.org/3'

# Construct the API request URL for the trending TV shows for the week
trending_tv_url = f'{base_url}/trending/tv/week?api_key={api_key}'

# Send the request to the API and retrieve the response
response = requests.get(trending_tv_url)

# Extract the JSON data from the response
trending_tv_data = response.json()

# Print out the taglines of the top 5 TV shows
trending_tv_data

# %%
import requests
from datetime import datetime, timedelta

# Your TMDB API key
api_key = 'f54fb2cf836df163dcdcab183a2bc3fc'

# The base URL for TMDB API requests
base_url = 'https://api.themoviedb.org/3'

# The date of today in YYYY-MM-DD format
today = datetime.now().strftime('%Y-%m-%d')

# Construct the API request URL for TV shows airing today
tv_airing_today_url = f'{base_url}/tv/on_the_air?api_key={api_key}&language=en-US&air_date={today}'

# Send the request to the API and retrieve the response
response = requests.get(tv_airing_today_url)

# Extract the JSON data from the response
tv_airing_today_data = response.json()

# Print out the names of all TV shows airing today in English
for tv_show in tv_airing_today_data['results']:
    if tv_show['original_language'] == 'en':
        print(tv_show['name'])

# %%
import requests

# Your TMDB API key
api_key = 'f54fb2cf836df163dcdcab183a2bc3fc'

# The base URL for TMDB API requests
base_url = 'https://api.themoviedb.org/3'

# The ID for "Money Heist" TV show in TMDB
tv_show_id = '71446'

# Construct the API request URL for the TV show credits
credits_url = f'{base_url}/tv/{tv_show_id}/credits?api_key={api_key}'

# Send the request to the API and retrieve the response
response = requests.get(credits_url)

# Extract the JSON data from the response
credits_data = response.json()

# Initialize counters for males and females
num_males = 0
num_females = 0

# Count the number of males and females in the cast
for cast_member in credits_data['cast']:
    if cast_member['gender'] == 1:
        num_females += 1
    elif cast_member['gender'] == 2:
        num_males += 1

# Print out the results
print(f'Number of males in the cast of "Money Heist": {num_males}')
print(f'Number of females in the cast of "Money Heist": {num_females}')

# %%
import requests
api_key = 'f54fb2cf836df163dcdcab183a2bc3fc'
base_url = 'https://api.themoviedb.org/3'

trending_tv_url = f'{base_url}/tv/1668?api_key={api_key}'

response = requests.get(trending_tv_url)
p = response.json()
print(p['overview'])
